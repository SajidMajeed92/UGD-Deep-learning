# %% [markdown]
# Date : May 12, 2024 \
# Fill the following before starting Exam
# *   Full Name:
# *   Batch with Program:
# *   contact No:
# *   Email Address:

# %% [markdown]
# Question 1:
# In figure given below you have to label each and every part of the given MLP which we discussed in class and find out the Total Number of Trainable parameters.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 2:
# * What do you understand by the term feed forward network and backward propagation.
# * what is activation function and why we use activation functions? Name any three Activation function.

# %% [markdown]
# Question 3:
#
# load Handwritten MNIST dataset from Keras Library API and create a Deep learning model for the given data set.
#
#
# *  Perform each step which you learn in the class.
#
# ![image.png](data:image/png;base64,...)
